# %%
# Clone the GitHub repo
# !git clone https://github.com/zs-barnes/RL-Sepsis-Prediction.git

# Set the path to the source data in the cloned repo
data_path = "/content/RL-Sepsis-Prediction/data/training_setA"

# Create the target directory if it doesn't exist
# !mkdir -p data/training_setA
# !mkdir -p models

# Copy the data from the cloned repo to the target location
# !cp -r RL-Sepsis-Prediction/data/training_setA/* data/training_setA/
# Out:
# Cloning into 'RL-Sepsis-Prediction'...
# remote: Enumerating objects: 20717, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 20717 (delta 112), reused 142 (delta 83), pack-reused 20534 (from 1)
# Receiving objects: 100% (20717/20717), 18.36 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (20091/20091), done.
# Updating files: 100% (20362/20362), done.

# %%
# !python sepsis_ensemble_80plus.py
# Out:
# Chargement des données depuis: data/training_setA
# Nombre total de fichiers: 20336
# Chargement des fichiers: 100% 20336/20336 [01:23<00:00, 244.56it/s]
# Forme des données originales: (308694, 10, 40), (308694,)
# Pourcentage de cas positifs original: 2.29%
# Forme des données d'entraînement équilibrées: (67524, 10, 40), (67524,)
# Pourcentage de cas positifs (entraînement équilibré): 50.00%
# Forme des données de test: (61183, 10, 40), (61183,)
# Pourcentage de cas positifs (test): 2.38%
# Poids des classes: [1. 1.]
# Forme des données de validation: (30591, 10, 40), (30591,)
# Forme des données de test final: (30592, 10, 40), (30592,)
# Utilisation de: cuda
# Entraînement de l'agent ensemble sur 5000 épisodes...
# Entraînement:   0% 0/5000 [00:06<?, ?it/s, reward=-70.30, epsilon=1.00, val_f1=0.7240, val_acc=0.5920]
# Épisode 10: Nouvelles meilleures métriques!
# F1: 0.7240, Accuracy: 0.5920
# Precision: 0.6597, Recall: 0.8021
# ...
